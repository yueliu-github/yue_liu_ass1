# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eebf1fe7-596c-4894-8143-efd4c3f32c57" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eebf1fe7-596c-4894-8143-efd4c3f32c57">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HW2_Cereals.csv to HW2_Cereals.csv

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('HW2_Cereals.csv')

# %%
shelfrating = df.boxplot(column='rating',by='shelf')
shelfrating.set_ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
corr=df.corr()

sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)
